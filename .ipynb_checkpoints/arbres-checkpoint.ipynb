# %%
import pandas as pd
import matplotlib.pyplot as plt   # installer via pip
import numpy as np

from tabulate import tabulate      #pip install tabulate

# %%
pd.set_option('display.max_columns', 50)    # Force pandas à afficher plus de 8 colonnes
pd.set_option('display.width', 1000)        # Force à afficher plus de 80 ligne

# Définit la taille des graphiques
# Get current size
fig_size = plt.rcParams["figure.figsize"]
 
# Prints: [8.0, 6.0]
print ("Current size:", fig_size)
 
# Set figure width to 15 and height to 10
fig_size[0] = 15.0
fig_size[1] = 10.0
plt.rcParams["figure.figsize"] = fig_size
# Out:
# Current size: [6.0, 4.0]

# %%
df = pd.read_csv("D:\BIGDATA\Datas_arbres.csv", sep=';')

# %%
df1 = df.groupby(["ARRONDISSEMENT","LIBELLEFRANCAIS"]).size().reset_index(name='NOMBRE')
print(df1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4ee8b158f267> in <module>
# ----> 1 df1 = df.groupby(["ARRONDISSEMENT","LIBELLEFRANCAIS"]).size().reset_index(name='NOMBRE')
#       2 print(df1)
#
# NameError: name 'df' is not defined

# %%
total_arbre = df.shape[0]
nb1 = df[(df["HAUTEUR_m"] == 0)].shape[0]
nb2 = df[(df["HAUTEUR_m"] > 0) & (df["HAUTEUR_m"] <= 100)].shape[0]
nb3 = df[(df["HAUTEUR_m"] > 100)].shape[0]
result = []

# [['Alice', 24], ['Bob', 19]] <-- Exemple
result.append(["Tous",total_arbre,''])
result.append(["=0",nb1,round(nb1/total_arbre*100,2)])
result.append(["0>?<=100",nb2,round(nb2/total_arbre*100,2)])
result.append([">100",nb3,round(nb3/total_arbre*100,2)])

print(tabulate(result, headers=['Arbres', 'Qte', '%'], tablefmt='orgtbl'))
# Out:
# | Arbres   |    Qte | %     |
# |----------+--------+-------|
# | Tous     | 203530 |       |
# | =0       |  34149 | 16.78 |
# | 0>?<=100 | 169256 | 83.16 |
# | >100     |    125 | 0.06  |

# %%
print("Nombre d'arbre par ARRONDISSEMENT/NOM ARBRE")
print(df.groupby(["ARRONDISSEMENT","LIBELLEFRANCAIS"]).size().reset_index(name='NOMBRE'))

print("Nombre d'arbre par ARRONDISSEMENT")
df1 = df.groupby(["ARRONDISSEMENT"]).size().reset_index(name='NOMBRE')

print(tabulate(df1, headers="keys", tablefmt="fancy_grid"))
# Out:
# Nombre d'arbre par ARRONDISSEMENT/NOM ARBRE
#         ARRONDISSEMENT                   LIBELLEFRANCAIS  NOMBRE
# 0     BOIS DE BOULOGNE                           Alisier      11
# 1     BOIS DE BOULOGNE                         Araucaria       1
# 2     BOIS DE BOULOGNE               Arbre aux mouchoirs       1
# 3     BOIS DE BOULOGNE           Arbre aux quarante écus       1
# 4     BOIS DE BOULOGNE                    Arbre de Judée       2
# 5     BOIS DE BOULOGNE                           Catalpa       4
# 6     BOIS DE BOULOGNE                 Cerisier à fleurs       6
# 7     BOIS DE BOULOGNE                            Charme      37
# 8     BOIS DE BOULOGNE                    Charme-Houblon      37
# 9     BOIS DE BOULOGNE                             Chêne      34
# 10    BOIS DE BOULOGNE                     Cyprès Chauve       2
# 11    BOIS DE BOULOGNE                             Cèdre       1
# 12    BOIS DE BOULOGNE                            Erable     465
# 13    BOIS DE BOULOGNE                            Fevier       6
# 14    BOIS DE BOULOGNE                             Frêne      20
# 15    BOIS DE BOULOGNE                    Frêne à fleurs      35
# 16    BOIS DE BOULOGNE                             Hêtre       3
# 17    BOIS DE BOULOGNE                                If       1
# 18    BOIS DE BOULOGNE                          Magnolia       1
# 19    BOIS DE BOULOGNE                        Marronnier    1317
# 20    BOIS DE BOULOGNE                          Merisier      48
# 21    BOIS DE BOULOGNE                       Micocoulier      52
# 22    BOIS DE BOULOGNE              Noisetier de Byzance     548
# 23    BOIS DE BOULOGNE                             Noyer       1
# 24    BOIS DE BOULOGNE                              Orme      47
# 25    BOIS DE BOULOGNE                   Orme de Sibérie      21
# 26    BOIS DE BOULOGNE                         Paulownia       7
# 27    BOIS DE BOULOGNE                               Pin      58
# 28    BOIS DE BOULOGNE                      Plaqueminier       1
# 29    BOIS DE BOULOGNE                           Platane     704
# ...                ...                               ...     ...
# 2200      VAL-DE-MARNE                              Orme      40
# 2201      VAL-DE-MARNE                   Orme de Sibérie      10
# 2202      VAL-DE-MARNE  Parrotie de Perse - Arbre de fer       8
# 2203      VAL-DE-MARNE                         Paulownia      20
# 2204      VAL-DE-MARNE                          Peuplier     267
# 2205      VAL-DE-MARNE                          Photinia       3
# 2206      VAL-DE-MARNE                               Pin       5
# 2207      VAL-DE-MARNE                      Plaqueminier      21
# 2208      VAL-DE-MARNE                           Platane    1498
# 2209      VAL-DE-MARNE                  Poirier à fleurs      79
# 2210      VAL-DE-MARNE                           Pommier       1
# 2211      VAL-DE-MARNE                  Pommier à fleurs      11
# 2212      VAL-DE-MARNE                  Pommier à fruits       5
# 2213      VAL-DE-MARNE                  Prunier à fleurs      47
# 2214      VAL-DE-MARNE                  Prunier à fruits      12
# 2215      VAL-DE-MARNE               Prunus Fleur n. sp.       1
# 2216      VAL-DE-MARNE                        Pterocarya     285
# 2217      VAL-DE-MARNE                          Robinier       4
# 2218      VAL-DE-MARNE                             Sapin       2
# 2219      VAL-DE-MARNE                             Saule       1
# 2220      VAL-DE-MARNE                         Savonnier      10
# 2221      VAL-DE-MARNE                           Sophora     279
# 2222      VAL-DE-MARNE                           Sorbier       1
# 2223      VAL-DE-MARNE                            Sureau       3
# 2224      VAL-DE-MARNE                             Thuya      10
# 2225      VAL-DE-MARNE                           Tilleul     674
# 2226      VAL-DE-MARNE                            Troene     121
# 2227      VAL-DE-MARNE                          Tulipier     104
# 2228      VAL-DE-MARNE                            Viorne       2
# 2229      VAL-DE-MARNE                         Virgilier       2
#
# [2230 rows x 3 columns]
# Nombre d'arbre par ARRONDISSEMENT
# ╒════╤═══════════════════╤══════════╕
# │    │ ARRONDISSEMENT    │   NOMBRE │
# ╞════╪═══════════════════╪══════════╡
# │  0 │ BOIS DE BOULOGNE  │     4085 │
# ├────┼───────────────────┼──────────┤
# │  1 │ BOIS DE VINCENNES │    11805 │
# ├────┼───────────────────┼──────────┤
# │  2 │ HAUTS-DE-SEINE    │     5409 │
# ├────┼───────────────────┼──────────┤
# │  3 │ PARIS 10E ARRDT   │     3422 │
# ├────┼───────────────────┼──────────┤
# │  4 │ PARIS 11E ARRDT   │     5810 │
# ├────┼───────────────────┼──────────┤
# │  5 │ PARIS 12E ARRDT   │    12479 │
# ├────┼───────────────────┼──────────┤
# │  6 │ PARIS 13E ARRDT   │    16849 │
# ├────┼───────────────────┼──────────┤
# │  7 │ PARIS 14E ARRDT   │    11937 │
# ├────┼───────────────────┼──────────┤
# │  8 │ PARIS 15E ARRDT   │    17219 │
# ├────┼───────────────────┼──────────┤
# │  9 │ PARIS 16E ARRDT   │    16945 │
# ├────┼───────────────────┼──────────┤
# │ 10 │ PARIS 17E ARRDT   │    10962 │
# ├────┼───────────────────┼──────────┤
# │ 11 │ PARIS 18E ARRDT   │    10188 │
# ├────┼───────────────────┼──────────┤
# │ 12 │ PARIS 19E ARRDT   │    14282 │
# ├────┼───────────────────┼──────────┤
# │ 13 │ PARIS 1ER ARRDT   │     1717 │
# ├────┼───────────────────┼──────────┤
# │ 14 │ PARIS 20E ARRDT   │    15413 │
# ├────┼───────────────────┼──────────┤
# │ 15 │ PARIS 2E ARRDT    │      542 │
# ├────┼───────────────────┼──────────┤
# │ 16 │ PARIS 3E ARRDT    │     1225 │
# ├────┼───────────────────┼──────────┤
# │ 17 │ PARIS 4E ARRDT    │     2762 │
# ├────┼───────────────────┼──────────┤
# │ 18 │ PARIS 5E ARRDT    │     2425 │
# ├────┼───────────────────┼──────────┤
# │ 19 │ PARIS 6E ARRDT    │     1784 │
# ├────┼───────────────────┼──────────┤
# │ 20 │ PARIS 7E ARRDT    │     8763 │
# ├────┼───────────────────┼──────────┤
# │ 21 │ PARIS 8E ARRDT    │     7270 │
# ├────┼───────────────────┼──────────┤
# │ 22 │ PARIS 9E ARRDT    │     1192 │
# ├────┼───────────────────┼──────────┤
# │ 23 │ SEINE-SAINT-DENIS │    11534 │
# ├────┼───────────────────┼──────────┤
# │ 24 │ VAL-DE-MARNE      │     7511 │
# ╘════╧═══════════════════╧══════════╛

# %%
# Set figure width to 15 and height to 5
fig_size[0] = 10.0
fig_size[1] = 5.0
plt.rcParams["figure.figsize"] = fig_size

df1 = df.groupby(["ARRONDISSEMENT"]).size().reset_index(name='NOMBRE')
print(df1.shape)
df1.plot(kind='bar',x='ARRONDISSEMENT',y='NOMBRE',color='red')
plt.show()
# Out:
# (25, 2)

# %%
# Set figure width to 15 and height to 10
fig_size[0] = 10.0
fig_size[1] = 35.0
plt.rcParams["figure.figsize"] = fig_size

df1 = df
df1 = df1[(df1["HAUTEUR_m"] >= 1) & (df["HAUTEUR_m"] <= 10000)]
df1 = df1.sort_values("LIBELLEFRANCAIS", ascending=True)
df1.plot(kind='barh',x='LIBELLEFRANCAIS',color='red')
plt.show()
df1 = null
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-cca7d877125a> in <module>
#       7 df1 = df[(df["HAUTEUR_m"] >= 1) & (df["HAUTEUR_m"] <= 10000)]
#       8 #df1 = df1.sort_values("LIBELLEFRANCAIS", ascending=True)
# ----> 9 df1.plot(kind='barh',x='LIBELLEFRANCAIS',color='red')
#      10 plt.show()
#      11 df1 = null
#
# c:\users\eric\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2939                           fontsize=fontsize, colormap=colormap, table=table,
#    2940                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# -> 2941                           sort_columns=sort_columns, **kwds)
#    2942     __call__.__doc__ = plot_frame.__doc__
#    2943
#
# c:\users\eric\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_core.py in plot_frame(data, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    1975                  yerr=yerr, xerr=xerr,
#    1976                  secondary_y=secondary_y, sort_columns=sort_columns,
# -> 1977                  **kwds)
#    1978
#    1979
#
# c:\users\eric\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1802         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1803
# -> 1804     plot_obj.generate()
#    1805     plot_obj.draw()
#    1806     return plot_obj.result
#
# c:\users\eric\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     258         self._compute_plot_data()
#     259         self._setup_subplots()
# --> 260         self._make_plot()
#     261         self._add_table()
#     262         self._make_legend()
#
# c:\users\eric\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_core.py in _make_plot(self)
#    1263                 rect = self._plot(ax, self.ax_pos + (i + 0.5) * w, y, w,
#    1264                                   start=start, label=label,
# -> 1265                                   log=self.log, **kwds)
#    1266             self._add_legend_handle(rect, label, index=i)
#    1267
#
# c:\users\eric\appdata\local\programs\python\python37\lib\site-packages\pandas\plotting\_core.py in _plot(cls, ax, x, y, w, start, log, **kwds)
#    1297     @classmethod
#    1298     def _plot(cls, ax, x, y, w, start=0, log=False, **kwds):
# -> 1299         return ax.barh(x, y, w, left=start, log=log, **kwds)
#    1300
#    1301     def _decorate_ticks(self, ax, name, ticklabels, start_edge, end_edge):
#
# c:\users\eric\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_axes.py in barh(self, y, width, height, left, align, **kwargs)
#    2595         kwargs.setdefault('orientation', 'horizontal')
#    2596         patches = self.bar(x=left, height=height, width=width, bottom=y,
# -> 2597                            align=align, **kwargs)
#    2598         return patches
#    2599
#
# c:\users\eric\appdata\local\programs\python\python37\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# c:\users\eric\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2436             elif orientation == 'horizontal':
#    2437                 r.sticky_edges.x.append(l)
# -> 2438             self.add_patch(r)
#    2439             patches.append(r)
#    2440
#
# c:\users\eric\appdata\local\programs\python\python37\lib\site-packages\matplotlib\axes\_base.py in add_patch(self, p)
#    1966         self._set_artist_props(p)
#    1967         if p.get_clip_path() is None:
# -> 1968             p.set_clip_path(self.patch)
#    1969         self._update_patch_limits(p)
#    1970         self.patches.append(p)
#
# c:\users\eric\appdata\local\programs\python\python37\lib\site-packages\matplotlib\artist.py in set_clip_path(self, path, transform)
#     713             if isinstance(path, Rectangle):
#     714                 self.clipbox = TransformedBbox(Bbox.unit(),
# --> 715                                                path.get_transform())
#     716                 self._clippath = None
#     717                 success = True
#
# c:\users\eric\appdata\local\programs\python\python37\lib\site-packages\matplotlib\patches.py in get_transform(self)
#     212         to the :class:`Patch`.
#     213         """
# --> 214         return self.get_patch_transform() + artist.Artist.get_transform(self)
#     215
#     216     def get_data_transform(self):
#
# c:\users\eric\appdata\local\programs\python\python37\lib\site-packages\matplotlib\patches.py in get_patch_transform(self)
#     756
#     757     def get_patch_transform(self):
# --> 758         self._update_patch_transform()
#     759         return self._rect_transform
#     760
#
# c:\users\eric\appdata\local\programs\python\python37\lib\site-packages\matplotlib\patches.py in _update_patch_transform(self)
#     735         bbox = transforms.Bbox.from_extents(x0, y0, x1, y1)
#     736         rot_trans = transforms.Affine2D()
# --> 737         rot_trans.rotate_deg_around(x0, y0, self.angle)
#     738         self._rect_transform = transforms.BboxTransformTo(bbox)
#     739         self._rect_transform += rot_trans
#
# c:\users\eric\appdata\local\programs\python\python37\lib\site-packages\matplotlib\transforms.py in rotate_deg_around(self, x, y, degrees)
#    1958         # Cast to float to avoid wraparound issues with uint8's
#    1959         x, y = float(x), float(y)
# -> 1960         return self.translate(-x, -y).rotate_deg(degrees).translate(x, y)
#    1961
#    1962     def translate(self, tx, ty):
#
# c:\users\eric\appdata\local\programs\python\python37\lib\site-packages\matplotlib\transforms.py in translate(self, tx, ty)
#    1970         translate_mtx = np.array(
#    1971             [[1.0, 0.0, tx], [0.0, 1.0, ty], [0.0, 0.0, 1.0]], float)
# -> 1972         self._mtx = np.dot(translate_mtx, self._mtx)
#    1973         self.invalidate()
#    1974         return self
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x0000023EAF78B400> (for post_execute):

# %%
# Set figure width to 15 and height to 10
fig_size[0] = 8.0
fig_size[1] = 8.0
plt.rcParams["figure.figsize"] = fig_size

df1 = df.groupby(["ARRONDISSEMENT"]).size().reset_index(name='NOMBRE')

labels = df1["ARRONDISSEMENT"]
sizes = df1["NOMBRE"]
#explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')


fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=False, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
